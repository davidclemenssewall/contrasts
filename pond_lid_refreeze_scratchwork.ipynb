# %% [markdown]
# # pond_lid_refreeze_scratchwork
#
# scratchwork estimating the timing of pond lid refreezing at station 2d

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# constants
L_frz = 334 # KJ/Kg

sb = 5.670374419e-8 # W⋅m⁻²⋅K⁻⁴
emiss = 0.985

rho_i = 917 # kg/m3

# %%
J_per_cm = 1000 * L_frz * rho_i / 100

LW_out_frz = emiss*sb*(273.15**4)

# %%
J_per_cm
# Out:
# 3062780.0

# %%
LW_out_frz
# Out:
# 310.92295496629254

# %%
J_per_cm/40/3600
# Out:
# 21.269305555555555

# %%
# Flux required to grow/melt cm of ice per day
J_per_cm / (3600*24)
# Out:
# 35.44884259259259
